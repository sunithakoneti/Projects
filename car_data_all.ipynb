# %%
import pandas as pd

# %%
df1 = pd.read_csv("delhi_all")
df2 = pd.read_csv("mumbai_all")
df3 = pd.read_csv("kolkata_all")
df4 = pd.read_csv("kochi_all")
df5 = pd.read_csv("gurgaon_all")
df6 = pd.read_csv("ghaziabad_all")
df7 = pd.read_csv("ahmedabad_all")
df8 = pd.read_csv("noida_all")

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8])

# %%
#df.to_csv("total_cars")

# %%
df_1 = pd.read_csv("total_cars")
df_2 = pd.read_csv("total_cars_data")

# %%
total_df = pd.concat([df_1,df_2],axis=0)

# %%
total_df.shape
# Out:
# (2890, 17)

# %%
# total_df.to_csv("total_used_cars")

# %%
total_df1 = total_df.drop(["Unnamed: 0.2","Unnamed: 0"],axis=1)
total_df1.drop["Unnamed: 0.1",axis=1]
# Out:
#       Unnamed: 0.1      state       city  year    make         model  \
# 0                0  CapitalUT      Delhi  2020    FORD      ECOSPORT
# 1                1  CapitalUT      Delhi  2016    Ford      Ecosport
# 2                2  CapitalUT      Delhi  2018    FORD      ECOSPORT
# 3                3  CapitalUT      Delhi  2019    FORD      ECOSPORT
# 4                4  CapitalUT      Delhi  2015    Ford      Ecosport
# ...            ...        ...        ...   ...     ...           ...
# 1070            46  Karnataka  Bangalore  2019  Maruti   New Wagon-R
# 1071            47  Karnataka  Bangalore  2021  Maruti   New Wagon-R
# 1072            48  Karnataka  Bangalore  2019  Maruti   New Wagon-R
# 1073            49  Karnataka  Bangalore  2021  Maruti   New Wagon-R
# 1074            50  Karnataka  Bangalore  2022  Maruti   New Wagon-R
#
#                        series transmission    fuel owner    emi  kilometers  \
# ...

# %%
total_df1.reset_index(inplace=True)

# %%
total_df1.head()
# Out:
#    index      state   city  year  make     model                   series  \
# 0      0  CapitalUT  Delhi  2020  FORD  ECOSPORT     TITANIUM 1.5L DIESEL
# 1      1  CapitalUT  Delhi  2016  Ford  Ecosport       1.5AMBIENTE TI VCT
# 2      2  CapitalUT  Delhi  2018  FORD  ECOSPORT     AMBIENTE 1.5L DIESEL
# 3      3  CapitalUT  Delhi  2019  FORD  ECOSPORT     TITANIUM 1.5L PETROL
# 4      4  CapitalUT  Delhi  2015  Ford  Ecosport  TITANIUM 1.5L PETROL AT
#
#   transmission    fuel owner    emi  kilometers  mileage  seating   price
# 0       Manual  Diesel  1st   15425       96075        9        5  789000
# 1       Manual  Petrol  1st   10792       55017        9        5  552000
# 2       Manual  Diesel  1st   13978       24931        9        5  715000
# 3       Manual  Petrol  1st   15503       22270        9        5  793000
# 4    Automatic  Petrol  2nd   10440       78906        9        5  534000

# %%
total_df1.drop("index",axis=1,inplace=True)

# %%
total_df1.head()
# Out:
#        state   city  year  make     model                   series  \
# 0  CapitalUT  Delhi  2020  FORD  ECOSPORT     TITANIUM 1.5L DIESEL
# 1  CapitalUT  Delhi  2016  Ford  Ecosport       1.5AMBIENTE TI VCT
# 2  CapitalUT  Delhi  2018  FORD  ECOSPORT     AMBIENTE 1.5L DIESEL
# 3  CapitalUT  Delhi  2019  FORD  ECOSPORT     TITANIUM 1.5L PETROL
# 4  CapitalUT  Delhi  2015  Ford  Ecosport  TITANIUM 1.5L PETROL AT
#
#   transmission    fuel owner    emi  kilometers  mileage  seating   price
# 0       Manual  Diesel  1st   15425       96075        9        5  789000
# 1       Manual  Petrol  1st   10792       55017        9        5  552000
# 2       Manual  Diesel  1st   13978       24931        9        5  715000
# 3       Manual  Petrol  1st   15503       22270        9        5  793000
# 4    Automatic  Petrol  2nd   10440       78906        9        5  534000

# %%
total_df1.isnull().sum()
# Out:
# state            0
# city             0
# year             0
# make             0
# model            0
# series          17
# transmission    17
# fuel             0
# owner            0
# emi              0
# kilometers       0
# mileage          0
# seating          0
# price            0
# dtype: int64

# %%
total_df1
# Out:
#           state       city  year    make         model  \
# 0     CapitalUT      Delhi  2020    FORD      ECOSPORT
# 1     CapitalUT      Delhi  2016    Ford      Ecosport
# 2     CapitalUT      Delhi  2018    FORD      ECOSPORT
# 3     CapitalUT      Delhi  2019    FORD      ECOSPORT
# 4     CapitalUT      Delhi  2015    Ford      Ecosport
# ...         ...        ...   ...     ...           ...
# 2885  Karnataka  Bangalore  2019  Maruti   New Wagon-R
# 2886  Karnataka  Bangalore  2021  Maruti   New Wagon-R
# 2887  Karnataka  Bangalore  2019  Maruti   New Wagon-R
# 2888  Karnataka  Bangalore  2021  Maruti   New Wagon-R
# 2889  Karnataka  Bangalore  2022  Maruti   New Wagon-R
#
#                        series transmission    fuel owner    emi  kilometers  \
# 0        TITANIUM 1.5L DIESEL       Manual  Diesel  1st   15425       96075
# 1          1.5AMBIENTE TI VCT       Manual  Petrol  1st   10792       55017
# ...
